# %%
import matplotlib.pyplot as plt 

input_values = [1, 2, 3, 4, 5]
squares = [1, 4, 9, 16, 25]
plt.plot(input_values, squares, linewidth = 3)

# Set chart title and labels axes. 
plt.title('Square Numbers', fontsize = 24)
plt.xlabel('Value', fontsize = 14)
plt.ylabel('Square of Value', fontsize = 14)

# Set size of tick labels. 
plt.tick_params(axis='both', labelsize = 14)
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.scatter(2, 4, s=200)
# Set chart title and label axes.
plt.title("Square Numbers", fontsize=24)
plt.xlabel("Value", fontsize=14)
plt.ylabel("Square of Value", fontsize=14)
# Set size of tick labels.
plt.tick_params(axis='both', which='major', labelsize=15)
plt.show()

# %%
x_values = [1,2,3,4,5]
y_values = [1,4,9,16,25]

plt.scatter(x_values, y_values, s=100)
plt.title('Squaters')
plt.xlabel('values')
plt.ylabel('squares')

plt.show()

# %% [markdown]
# ### Calculating data automatically

# %%
import matplotlib.pyplot as plt
x_values = list(range(1, 1001))
y_values = [x**2 for x in x_values]

plt.scatter(x_values, y_values, edgecolor='none', s=40)
# Set the range for each axis
plt.axis([0,1100, 0, 1100000])

plt.show()

# %% [markdown]
# ### Removing outlines from data points

# %% [markdown]
# plt.scatter(x_values, y_values, edgecolor='none', s=40)

# %% [markdown]
# ### Defining custom colors

# %%
plt.scatter(x_values, y_values, c='red', edgecolor='none', s=40)

# %% [markdown]
# ### Using a colormap

# %%
import matplotlib.pyplot as plt 

x_values = list(range(1001))
y_values = [x**2 for x in x_values]

plt.scatter(x_values, y_values, c=y_values, cmap=plt.cm.Blues,
            edgecolor='none', s=40)

plt.savefig('squares_plot.png', bbox_inches='tight')

# %% [markdown]
# ## Try it yourself

# %%
cube = [1, 2, 3, 4, 5]
cube_3 = [1, 8, 27, 64, 125]

plt.scatter(cube, cube_3, c=cube_3, cmap=plt.cm.Blues , edgecolor='none')

# %%
x_values = list(range(5001))
y_values = [x**3 for x in x_values]

plt.scatter(x_values, y_values, s=10, c=y_values, cmap=plt.cm.Blues)

# %% [markdown]
# ### Random Walks

# %% [markdown]
# To generate data for a random walk
# visually the data generated
